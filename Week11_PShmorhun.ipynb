# %% [markdown]
# # Week 11 - Introduction to Modeling, part 2

# %% [markdown]
# # 1. Lesson - No lesson this week

# %% [markdown]
# # 2. Weekly graph question

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import root_mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

# %% [markdown]
# The book names one of Vonnegut's rules as "keep it simple" and another as "have the guts to cut."  Here is some data from the previous week's lesson.  If you had to cut one of the two plots below, which would it be?  Which seems more interesting or important?  Explain.  (Should "amount of training data used" or "number of estimators" be on the x-axis.)

# %%
np.random.seed(0)
num_points = 10000
feature_1a = np.random.random(size = num_points) * 3
feature_2a = np.random.random(size = num_points) * 3
feature_3a = np.random.random(size = num_points) * 3
train_target = (feature_1a - 2 * feature_2a) * feature_3a + np.random.normal(size = num_points)
feature_1b = np.random.random(size = num_points) * 3
feature_2b = np.random.random(size = num_points) * 3
feature_3b = np.random.random(size = num_points) * 3
test_target = (feature_1b - 2 * feature_2b) * feature_3b + np.random.normal(size = num_points)
train_df = pd.DataFrame({"f1": feature_1a, "f2": feature_2a, "f3": feature_3a})
test_df = pd.DataFrame({"f1": feature_1b, "f2": feature_2b, "f3": feature_3b})
rf = RandomForestRegressor()
rf.fit(train_df.values, train_target)
# Out:
# RandomForestRegressor()

# %%
rmse_lst = list()
rf = RandomForestRegressor()
for x in range(round(num_points / 20), num_points, round(num_points / 20)):
    rf.fit(train_df.values[0:x,:], train_target[0:x])
    rmse_lst.append(root_mean_squared_error(rf.predict(test_df.values), test_target))

import matplotlib.pyplot as plt

# %%
plt.plot(rmse_lst)
plt.xlabel("Amount of training data used (20 = max)")
plt.ylabel("Loss function")
# Out:
# Text(0, 0.5, 'Loss function')

# %%
num_trees_lst = list()
for n_estimators in range(1, 100, 3):
    rf = RandomForestRegressor(n_estimators = n_estimators)
    rf.fit(train_df.values, train_target)
    num_trees_lst.append(root_mean_squared_error(rf.predict(test_df.values), test_target))

# %%
plt.plot(num_trees_lst)
plt.xlabel("Number of estimators (trees)")
plt.ylabel("Loss function")
# Out:
# Text(0, 0.5, 'Loss function')

# %% [markdown]
# ### If you had to cut one of the two plots below, which would it be?  Which seems more interesting or important?  Explain. (Should "amount of training data used" or "number of estimators" be on the x-axis.)
# - The first plot shows RMSE as the size of the training set increases, with the RMSE dropping as the size of the training data is increased. As more data is added, the model "learns" to build a better representation of the underlying data and generalizes better, lowering the error.
# - The second plot shows the RMSE as the number of estimators in the decision tree model is increased, with the RMSE dropping as the complexity of the model is increased. As more trees are added, the model benefits from the ensemble effect, which will result in improved model as the model averages across many trees, improving accuracy and lowering error.
# - If I had to only pick one model, I'd go with the first plot because the learning curve (amount of training data used) offers a more fundamental insight into how the model improves with more data. Thus, having "amount of training data used" on the x-axis would be more interesting and important for understanding the overall behavior of the model.

# %% [markdown]
# # 3. Working on your datasets

# %% [markdown]
# This week, you will do the same types of exercises as last week, but you should use your chosen datasets that someone in your class found last semester. (They likely will not be the particular datasets that you found yourself.)
#
# Here are some types of analysis you can do:
#
# * Implement a random forest model.
# * Perform cross-validation.
# * Tune hyperparameters.
# * Evaluate a performance metric.
#
# If you like, you can try other types of models, too (beyond linear regression and random forest) although you will have many opportunities to do that next semester.

# %% [markdown]
# ### Random Forest Classifier

# %%
# Scikit-learn (Machine Learning)
from sklearn.model_selection import (
    train_test_split, 
    cross_val_score, 
    GridSearchCV, 
    RandomizedSearchCV, 
    RepeatedKFold
)
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score, 
    confusion_matrix, 
    classification_report
)

# preprocess data
motion_df = pd.read_csv("capstone_datasets/nfl-playing-surface-analytics/MotionData.csv")

# 1. Prepare the features (drop leakage columns)
X = motion_df.drop(columns=[
    'Injury', 'DM_M1', 'DM_M7', 'DM_M28', 'DM_M42', 'PlayKey', 'PlayerKey', 'GameID'
])

# 2. One-hot encode categorical columns
X = pd.get_dummies(X, dummy_na=True, drop_first=True)

# For a cuDF DataFrame with some boolean columns:
for col in X.columns:
    if X[col].dtype == 'bool':
        X[col] = X[col].astype('int32')


# 3. Prepare the binary target (0 = no injury, 1 = injury)
y = motion_df['Injury'].copy()
y_binary = y.copy()
y_binary[y_binary > 0] = 1

X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y_binary, 
    test_size=0.2,     # 20% of data will be held out for testing
    random_state=42,   # For reproducibility
    shuffle=True       # Data is shuffled by default; can be set to False if needed
)

# Initialize and train a RandomForestClassifier
rf = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=42)
rf.fit(X_train, y_train)

# Predict and evaluate
y_pred = rf.predict(X_test)
acc = accuracy_score(y_test, y_pred)
print("Test Accuracy:", acc)
# Out:
# Test Accuracy: 0.9996629087231732

# %%
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
# 8. Predict and evaluate
y_pred = rf.predict(X_test)
y_pred_proba = rf.predict_proba(X_test)[:, 1]

# Classification report
print(classification_report(y_test, y_pred))

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title("Confusion Matrix")
plt.show() # great accuracy but very poor recal
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     53374
#            1       1.00      0.25      0.40        24
#
#     accuracy                           1.00     53398
#    macro avg       1.00      0.62      0.70     53398
# weighted avg       1.00      1.00      1.00     53398

# %% [markdown]
# ### Resampling with SMOTE, then Cross Validation through GridSearchCV

# %%
import time
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline

# Start timing
start_time = time.time()

# Define the pipeline: first SMOTE, then the classifier.
pipeline = Pipeline(steps=[
    ('smote', SMOTE(random_state=42)),
    ('classifier', RandomForestClassifier(random_state=0))
])

# Parameter grid for grid search.
grid_params = {
    'classifier__max_depth': [2, 3, 4, 5, None],
    'classifier__min_samples_leaf': [1, 2, 3],
    'classifier__min_samples_split': [2, 3, 4],
    'classifier__max_features': [2, 3, 4],
    'classifier__n_estimators': [75, 100, 125, 150]
}

# Define the scoring metrics (ensure 'scoring' is defined appropriately).
scoring = {
    'precision': 'precision',
    'recall': 'recall',
    'f1': 'f1'
}

# Initialize GridSearchCV.
grid_cv = GridSearchCV(pipeline, 
                       grid_params, 
                       scoring=scoring, 
                       cv=3,
                       n_jobs=-1, 
                       refit='f1',
                       verbose=3)

# Fit on the training data.
grid_cv.fit(X_train, y_train)

# Print execution time.
execution_time = time.time() - start_time
print(f"\nExecution Time: {execution_time:.2f}s\n")

# Print the best parameters and best f1 score.
print("Best Parameters:")
print(grid_cv.best_params_)
print(f"\nBest F1 Score (CV): {grid_cv.best_score_:.4f}\n")

# Display all cross-validation results in a sorted DataFrame.
cv_results = pd.DataFrame(grid_cv.cv_results_)
# Sort by rank_test_f1 (lowest rank is the best)
cv_results = cv_results.sort_values('rank_test_f1')
print("Grid Search CV Results (top 5 rows):")
print(cv_results[['params', 'mean_test_f1', 'std_test_f1', 'rank_test_f1']].head())

# If you have a test set, evaluate on it:
if 'X_test' in globals() and 'y_test' in globals():
    y_pred = grid_cv.predict(X_test)
    print("\nClassification Report on Test Set:")
    print(classification_report(y_test, y_pred))
    
    print("Confusion Matrix on Test Set:")
    print(confusion_matrix(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 540 candidates, totalling 1620 fits
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=125; f1: (test=0.254) precision: (test=0.205) recall: (test=0.333) total time=   7.1s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=75; f1: (test=0.171) precision: (test=0.115) recall: (test=0.333) total time=   7.4s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=75; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   9.6s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=75; f1: (test=0.333) precision: (test=0.667) recall: (test=0.222) total time=   7.8s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=75; f1: (test=0.333) precision: (test=0.667) recall: (test=0.222) total time=  10.4s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=75; f1: (test=0.171) precision: (test=0.115) recall: (test=0.333) total time=  11.7s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=100; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   9.5s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=75; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=  11.6s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=100; f1: (test=0.429) precision: (test=0.600) recall: (test=0.333) total time=  11.6s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=  13.3s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=125; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=  10.8s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=125; f1: (test=0.254) precision: (test=0.205) recall: (test=0.333) total time=  11.2s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=125; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=  12.1s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; f1: (test=0.429) precision: (test=0.600) recall: (test=0.333) total time=  15.8s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=4, classifier__n_estimators=75; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   8.5s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=150; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=  15.0s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=150; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=  14.9s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=150; f1: (test=0.391) precision: (test=0.474) recall: (test=0.333) total time=  12.4s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=125; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=  15.7s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=  16.5s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=150; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=  12.2s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=150; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=  13.0s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=100; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=  15.3s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=125; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=  17.3s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=4, classifier__n_estimators=125; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   8.7s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=150; f1: (test=0.391) precision: (test=0.474) recall: (test=0.333) total time=  17.7s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=4, classifier__n_estimators=75; f1: (test=0.171) precision: (test=0.115) recall: (test=0.333) total time=  12.9s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=4, classifier__n_estimators=75; f1: (test=0.333) precision: (test=0.667) recall: (test=0.222) total time=  11.6s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=75; f1: (test=0.333) precision: (test=0.667) recall: (test=0.222) total time=   4.9s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=75; f1: (test=0.171) precision: (test=0.115) recall: (test=0.333) total time=   6.3s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=4, classifier__n_estimators=150; f1: (test=0.391) precision: (test=0.474) recall: (test=0.333) total time=   9.4s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=75; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   4.8s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=4, classifier__n_estimators=100; f1: (test=0.429) precision: (test=0.600) recall: (test=0.333) total time=  13.1s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=4, classifier__n_estimators=100; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=  11.5s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=4, classifier__n_estimators=150; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   8.4s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=4, classifier__n_estimators=100; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=  12.7s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=4, classifier__n_estimators=125; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=  11.1s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=4, classifier__n_estimators=125; f1: (test=0.254) precision: (test=0.205) recall: (test=0.333) total time=  12.8s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=1, classifier__min_samples_split=4, classifier__n_estimators=150; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=  11.5s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=100; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   5.7s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=100; f1: (test=0.429) precision: (test=0.600) recall: (test=0.333) total time=   7.1s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=100; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=   6.6s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=125; f1: (test=0.250) precision: (test=0.200) recall: (test=0.333) total time=   5.6s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=125; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=   5.5s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=125; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   5.5s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=75; f1: (test=0.171) precision: (test=0.115) recall: (test=0.333) total time=   3.7s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=75; f1: (test=0.333) precision: (test=0.667) recall: (test=0.222) total time=   3.4s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=75; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   3.3s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=150; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   5.4s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=100; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   3.3s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=150; f1: (test=0.383) precision: (test=0.450) recall: (test=0.333) total time=   7.7s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=100; f1: (test=0.429) precision: (test=0.600) recall: (test=0.333) total time=   5.1s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=150; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=   7.4s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=125; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=   4.3s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=100; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=   5.9s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=75; f1: (test=0.171) precision: (test=0.115) recall: (test=0.333) total time=   4.1s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=75; f1: (test=0.333) precision: (test=0.667) recall: (test=0.222) total time=   4.0s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=75; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   3.9s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=100; f1: (test=0.429) precision: (test=0.600) recall: (test=0.333) total time=   4.2s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=100; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=   3.7s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=150; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   5.7s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=125; f1: (test=0.250) precision: (test=0.200) recall: (test=0.333) total time=   7.4s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=150; f1: (test=0.383) precision: (test=0.450) recall: (test=0.333) total time=   6.4s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=100; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   3.4s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=125; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   7.6s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=150; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=   8.1s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=125; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   5.1s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=150; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   4.9s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=75; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   3.9s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=75; f1: (test=0.333) precision: (test=0.667) recall: (test=0.222) total time=   4.7s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=125; f1: (test=0.250) precision: (test=0.200) recall: (test=0.333) total time=   7.9s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=125; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=   7.7s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=75; f1: (test=0.171) precision: (test=0.115) recall: (test=0.333) total time=   5.7s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=100; f1: (test=0.429) precision: (test=0.600) recall: (test=0.333) total time=   4.9s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=100; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=   5.2s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=100; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   5.1s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=150; f1: (test=0.383) precision: (test=0.450) recall: (test=0.333) total time=   8.7s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=150; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=   8.4s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=125; f1: (test=0.250) precision: (test=0.200) recall: (test=0.333) total time=   5.7s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=125; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=   5.4s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=125; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   5.1s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=75; f1: (test=0.333) precision: (test=0.667) recall: (test=0.222) total time=   4.4s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=75; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   4.3s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=75; f1: (test=0.171) precision: (test=0.115) recall: (test=0.333) total time=   5.0s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=100; f1: (test=0.429) precision: (test=0.600) recall: (test=0.333) total time=   5.1s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=100; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   4.7s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=150; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=   7.8s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=150; f1: (test=0.383) precision: (test=0.450) recall: (test=0.333) total time=   8.7s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=100; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=   6.2s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=150; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   8.2s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=125; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=   5.0s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=125; f1: (test=0.250) precision: (test=0.200) recall: (test=0.333) total time=   5.7s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=75; f1: (test=0.333) precision: (test=0.667) recall: (test=0.222) total time=   4.3s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=75; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   4.4s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=75; f1: (test=0.171) precision: (test=0.115) recall: (test=0.333) total time=   5.3s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=125; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   7.7s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=100; f1: (test=0.429) precision: (test=0.600) recall: (test=0.333) total time=   5.3s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=100; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=   4.9s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=100; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   5.2s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=150; f1: (test=0.383) precision: (test=0.450) recall: (test=0.333) total time=   8.5s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=150; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=   8.3s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=150; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   8.3s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=125; f1: (test=0.250) precision: (test=0.200) recall: (test=0.333) total time=   5.9s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=125; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=   5.5s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=125; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   5.4s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=150; f1: (test=0.383) precision: (test=0.450) recall: (test=0.333) total time=   5.5s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=75; f1: (test=0.143) precision: (test=0.105) recall: (test=0.222) total time=   4.6s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=75; f1: (test=0.018) precision: (test=0.009) recall: (test=0.370) total time=   5.8s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; f1: (test=0.211) precision: (test=0.200) recall: (test=0.222) total time=   4.9s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=150; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=   7.1s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=75; f1: (test=0.030) precision: (test=0.016) recall: (test=0.296) total time=   5.9s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; f1: (test=0.060) precision: (test=0.033) recall: (test=0.296) total time=   5.1s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=2, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=150; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=   8.0s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=100; f1: (test=0.035) precision: (test=0.019) recall: (test=0.333) total time=   6.4s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=125; f1: (test=0.164) precision: (test=0.130) recall: (test=0.222) total time=   5.4s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=125; f1: (test=0.038) precision: (test=0.020) recall: (test=0.296) total time=   5.2s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=75; f1: (test=0.018) precision: (test=0.009) recall: (test=0.370) total time=   4.8s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=75; f1: (test=0.143) precision: (test=0.105) recall: (test=0.222) total time=   4.6s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=75; f1: (test=0.030) precision: (test=0.016) recall: (test=0.296) total time=   4.6s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=125; f1: (test=0.030) precision: (test=0.016) recall: (test=0.333) total time=   7.3s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=100; f1: (test=0.211) precision: (test=0.200) recall: (test=0.222) total time=   5.1s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=100; f1: (test=0.060) precision: (test=0.033) recall: (test=0.296) total time=   5.1s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=100; f1: (test=0.035) precision: (test=0.019) recall: (test=0.333) total time=   6.2s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=150; f1: (test=0.171) precision: (test=0.140) recall: (test=0.222) total time=   8.3s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=150; f1: (test=0.030) precision: (test=0.016) recall: (test=0.333) total time=   8.7s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=150; f1: (test=0.054) precision: (test=0.030) recall: (test=0.296) total time=   8.2s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=125; f1: (test=0.030) precision: (test=0.016) recall: (test=0.333) total time=   5.5s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=125; f1: (test=0.164) precision: (test=0.130) recall: (test=0.222) total time=   7.2s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=4, classifier__n_estimators=75; f1: (test=0.018) precision: (test=0.009) recall: (test=0.370) total time=   5.5s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=125; f1: (test=0.038) precision: (test=0.020) recall: (test=0.296) total time=   7.5s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=150; f1: (test=0.171) precision: (test=0.140) recall: (test=0.222) total time=   6.9s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=150; f1: (test=0.054) precision: (test=0.030) recall: (test=0.296) total time=   7.0s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=4, classifier__n_estimators=75; f1: (test=0.143) precision: (test=0.105) recall: (test=0.222) total time=   6.2s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=150; f1: (test=0.030) precision: (test=0.016) recall: (test=0.333) total time=   8.0s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=4, classifier__n_estimators=100; f1: (test=0.035) precision: (test=0.019) recall: (test=0.333) total time=   6.0s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=4, classifier__n_estimators=75; f1: (test=0.030) precision: (test=0.016) recall: (test=0.296) total time=   6.6s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=4, classifier__n_estimators=100; f1: (test=0.211) precision: (test=0.200) recall: (test=0.222) total time=   5.6s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=4, classifier__n_estimators=125; f1: (test=0.164) precision: (test=0.130) recall: (test=0.222) total time=   5.4s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=4, classifier__n_estimators=125; f1: (test=0.030) precision: (test=0.016) recall: (test=0.333) total time=   5.9s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=4, classifier__n_estimators=100; f1: (test=0.060) precision: (test=0.033) recall: (test=0.296) total time=   7.2s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=4, classifier__n_estimators=125; f1: (test=0.038) precision: (test=0.020) recall: (test=0.296) total time=   7.0s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=75; f1: (test=0.030) precision: (test=0.016) recall: (test=0.296) total time=   4.7s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=75; f1: (test=0.143) precision: (test=0.105) recall: (test=0.222) total time=   5.2s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=100; f1: (test=0.035) precision: (test=0.019) recall: (test=0.333) total time=   5.6s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=75; f1: (test=0.018) precision: (test=0.009) recall: (test=0.370) total time=   6.8s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=4, classifier__n_estimators=150; f1: (test=0.030) precision: (test=0.016) recall: (test=0.333) total time=   8.1s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=100; f1: (test=0.211) precision: (test=0.200) recall: (test=0.222) total time=   5.5s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=100; f1: (test=0.060) precision: (test=0.033) recall: (test=0.296) total time=   5.0s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=4, classifier__n_estimators=150; f1: (test=0.171) precision: (test=0.140) recall: (test=0.222) total time=   9.7s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=1, classifier__min_samples_split=4, classifier__n_estimators=150; f1: (test=0.054) precision: (test=0.030) recall: (test=0.296) total time=   9.8s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=75; f1: (test=0.018) precision: (test=0.009) recall: (test=0.370) total time=   5.5s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=125; f1: (test=0.030) precision: (test=0.016) recall: (test=0.333) total time=   8.5s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=75; f1: (test=0.143) precision: (test=0.105) recall: (test=0.222) total time=   6.0s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=125; f1: (test=0.164) precision: (test=0.130) recall: (test=0.222) total time=   8.5s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=150; f1: (test=0.030) precision: (test=0.016) recall: (test=0.333) total time=   7.9s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=75; f1: (test=0.030) precision: (test=0.016) recall: (test=0.296) total time=   5.8s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=125; f1: (test=0.038) precision: (test=0.020) recall: (test=0.296) total time=   8.8s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=150; f1: (test=0.171) precision: (test=0.140) recall: (test=0.222) total time=   8.3s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=100; f1: (test=0.035) precision: (test=0.019) recall: (test=0.333) total time=   6.4s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=100; f1: (test=0.211) precision: (test=0.200) recall: (test=0.222) total time=   6.2s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=150; f1: (test=0.054) precision: (test=0.030) recall: (test=0.296) total time=   9.1s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=100; f1: (test=0.060) precision: (test=0.033) recall: (test=0.296) total time=   6.9s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=125; f1: (test=0.164) precision: (test=0.130) recall: (test=0.222) total time=   6.6s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=125; f1: (test=0.030) precision: (test=0.016) recall: (test=0.333) total time=   7.1s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=75; f1: (test=0.143) precision: (test=0.105) recall: (test=0.222) total time=   3.8s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=75; f1: (test=0.030) precision: (test=0.016) recall: (test=0.296) total time=   3.6s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=150; f1: (test=0.030) precision: (test=0.016) recall: (test=0.333) total time=   7.1s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=125; f1: (test=0.038) precision: (test=0.020) recall: (test=0.296) total time=   8.1s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=75; f1: (test=0.018) precision: (test=0.009) recall: (test=0.370) total time=   6.2s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=150; f1: (test=0.054) precision: (test=0.030) recall: (test=0.296) total time=   6.7s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=125; f1: (test=0.030) precision: (test=0.016) recall: (test=0.333) total time=   4.6s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=150; f1: (test=0.171) precision: (test=0.140) recall: (test=0.222) total time=   8.9s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=150; f1: (test=0.030) precision: (test=0.016) recall: (test=0.333) total time=   5.3s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=100; f1: (test=0.035) precision: (test=0.019) recall: (test=0.333) total time=   7.8s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=100; f1: (test=0.211) precision: (test=0.200) recall: (test=0.222) total time=   7.7s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=75; f1: (test=0.018) precision: (test=0.009) recall: (test=0.370) total time=   4.5s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=150; f1: (test=0.171) precision: (test=0.140) recall: (test=0.222) total time=   6.3s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=100; f1: (test=0.060) precision: (test=0.033) recall: (test=0.296) total time=   8.6s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=125; f1: (test=0.164) precision: (test=0.130) recall: (test=0.222) total time=   7.8s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=100; f1: (test=0.035) precision: (test=0.019) recall: (test=0.333) total time=   4.5s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=150; f1: (test=0.054) precision: (test=0.030) recall: (test=0.296) total time=   6.3s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=75; f1: (test=0.030) precision: (test=0.016) recall: (test=0.296) total time=   5.6s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=75; f1: (test=0.143) precision: (test=0.105) recall: (test=0.222) total time=   6.0s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=125; f1: (test=0.038) precision: (test=0.020) recall: (test=0.296) total time=   8.9s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=100; f1: (test=0.211) precision: (test=0.200) recall: (test=0.222) total time=   6.1s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=125; f1: (test=0.164) precision: (test=0.130) recall: (test=0.222) total time=   5.2s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=125; f1: (test=0.038) precision: (test=0.020) recall: (test=0.296) total time=   4.8s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=75; f1: (test=0.018) precision: (test=0.009) recall: (test=0.370) total time=   3.1s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=75; f1: (test=0.143) precision: (test=0.105) recall: (test=0.222) total time=   2.8s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=150; f1: (test=0.030) precision: (test=0.016) recall: (test=0.333) total time=   5.3s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=150; f1: (test=0.171) precision: (test=0.140) recall: (test=0.222) total time=   5.0s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=125; f1: (test=0.030) precision: (test=0.016) recall: (test=0.333) total time=   6.9s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=100; f1: (test=0.060) precision: (test=0.033) recall: (test=0.296) total time=   8.0s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=75; f1: (test=0.030) precision: (test=0.016) recall: (test=0.296) total time=   5.8s
# [CV 2/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=100; f1: (test=0.211) precision: (test=0.200) recall: (test=0.222) total time=   6.3s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=150; f1: (test=0.054) precision: (test=0.030) recall: (test=0.296) total time=   9.3s
# [CV 3/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=125; f1: (test=0.038) precision: (test=0.020) recall: (test=0.296) total time=   5.6s
# [CV 1/3] END classifier__max_depth=2, classifier__max_features=3, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=100; f1: (test=0.035) precision: (test=0.019) recall: (test=0.333) total time=   7.8s
# ...
# [CV 1/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=125; f1: (test=0.500) precision: (test=1.000) recall: (test=0.333) total time= 1.1min
# [CV 1/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=100; f1: (test=0.500) precision: (test=1.000) recall: (test=0.333) total time=  44.7s
# [CV 3/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=125; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=  59.8s
# [CV 1/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=75; f1: (test=0.500) precision: (test=1.000) recall: (test=0.333) total time=  40.6s
# [CV 1/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=125; f1: (test=0.500) precision: (test=1.000) recall: (test=0.333) total time=  48.3s
# [CV 3/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=125; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=  48.0s
# [CV 2/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=150; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time= 1.0min
# [CV 3/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=100; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=  52.4s
# [CV 2/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=100; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=  40.4s
# [CV 1/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=150; f1: (test=0.500) precision: (test=1.000) recall: (test=0.333) total time= 1.1min
# [CV 2/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=125; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time=  56.6s
# [CV 1/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=75; f1: (test=0.500) precision: (test=1.000) recall: (test=0.333) total time=  28.4s
# [CV 3/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=75; f1: (test=0.400) precision: (test=0.875) recall: (test=0.259) total time=  27.0s
# [CV 3/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=150; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=  56.9s
# [CV 3/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=150; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time= 1.2min
# [CV 3/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=100; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=  50.3s
# [CV 1/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=100; f1: (test=0.500) precision: (test=1.000) recall: (test=0.333) total time=  55.1s
# [CV 2/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=75; f1: (test=0.343) precision: (test=0.750) recall: (test=0.222) total time=  37.9s
# [CV 3/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=125; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=  49.2s
# [CV 1/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=100; f1: (test=0.500) precision: (test=1.000) recall: (test=0.333) total time=  39.5s
# [CV 3/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=100; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=  37.7s
# [CV 2/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=75; f1: (test=0.343) precision: (test=0.750) recall: (test=0.222) total time=  26.8s
# [CV 3/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=75; f1: (test=0.400) precision: (test=0.875) recall: (test=0.259) total time=  30.3s
# [CV 1/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=75; f1: (test=0.500) precision: (test=1.000) recall: (test=0.333) total time=  32.9s
# [CV 2/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=100; f1: (test=0.353) precision: (test=0.857) recall: (test=0.222) total time=  49.2s
# [CV 1/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=150; f1: (test=0.500) precision: (test=1.000) recall: (test=0.333) total time= 1.4min
# [CV 2/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=150; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time= 1.3min
# [CV 1/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=125; f1: (test=0.500) precision: (test=1.000) recall: (test=0.333) total time= 1.1min
# [CV 3/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=125; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=  47.3s
# [CV 2/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=150; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time= 1.1min
# [CV 2/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=125; f1: (test=0.364) precision: (test=1.000) recall: (test=0.222) total time= 1.1min
# [CV 2/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=125; f1: (test=0.353) precision: (test=0.857) recall: (test=0.222) total time=  50.4s
# [CV 1/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=125; f1: (test=0.500) precision: (test=1.000) recall: (test=0.333) total time=  51.2s
# [CV 1/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=75; f1: (test=0.500) precision: (test=1.000) recall: (test=0.333) total time=  26.7s
# [CV 1/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=150; f1: (test=0.500) precision: (test=1.000) recall: (test=0.333) total time= 1.1min
# [CV 1/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=150; f1: (test=0.500) precision: (test=1.000) recall: (test=0.333) total time=  51.6s
# [CV 3/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=150; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time= 1.1min
# [CV 1/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=100; f1: (test=0.500) precision: (test=1.000) recall: (test=0.333) total time=  45.0s
# [CV 3/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=100; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=  42.3s
# [CV 2/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=75; f1: (test=0.343) precision: (test=0.750) recall: (test=0.222) total time=  29.5s
# [CV 2/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=100; f1: (test=0.353) precision: (test=0.857) recall: (test=0.222) total time=  44.5s
# [CV 1/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=125; f1: (test=0.500) precision: (test=1.000) recall: (test=0.333) total time=  41.5s
# [CV 2/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=150; f1: (test=0.353) precision: (test=0.857) recall: (test=0.222) total time=  54.9s
# [CV 3/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=75; f1: (test=0.400) precision: (test=0.875) recall: (test=0.259) total time=  28.4s
# [CV 3/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=2, classifier__n_estimators=150; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=  53.1s
# [CV 2/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=100; f1: (test=0.353) precision: (test=0.857) recall: (test=0.222) total time=  27.1s
# [CV 3/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=125; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=  43.2s
# [CV 2/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=125; f1: (test=0.353) precision: (test=0.857) recall: (test=0.222) total time=  45.3s
# [CV 1/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=150; f1: (test=0.500) precision: (test=1.000) recall: (test=0.333) total time=  42.6s
# [CV 1/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=100; f1: (test=0.500) precision: (test=1.000) recall: (test=0.333) total time=  30.4s
# [CV 3/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=100; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=  29.2s
# [CV 2/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=150; f1: (test=0.353) precision: (test=0.857) recall: (test=0.222) total time=  42.0s
# [CV 1/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=125; f1: (test=0.500) precision: (test=1.000) recall: (test=0.333) total time=  29.7s
# [CV 3/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=125; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=  26.3s
# [CV 2/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=125; f1: (test=0.353) precision: (test=0.857) recall: (test=0.222) total time=  27.1s
# [CV 3/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=3, classifier__n_estimators=150; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=  46.2s
# [CV 3/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=150; f1: (test=0.412) precision: (test=1.000) recall: (test=0.259) total time=  27.1s
# [CV 1/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=150; f1: (test=0.500) precision: (test=1.000) recall: (test=0.333) total time=  30.1s
# [CV 2/3] END classifier__max_depth=None, classifier__max_features=4, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=150; f1: (test=0.353) precision: (test=0.857) recall: (test=0.222) total time=  30.3s
#
# Execution Time: 1194.84s
#
# Best Parameters:
# {'classifier__max_depth': None, 'classifier__max_features': 2, 'classifier__min_samples_leaf': 1, 'classifier__min_samples_split': 2, 'classifier__n_estimators': 75}
#
# Best F1 Score (CV): 0.4251
#
# Grid Search CV Results (top 5 rows):
#                                                 params  mean_test_f1  \
# 483  {'classifier__max_depth': None, 'classifier__m...      0.425134
# 482  {'classifier__max_depth': None, 'classifier__m...      0.425134
# 481  {'classifier__max_depth': None, 'classifier__m...      0.425134
# 480  {'classifier__max_depth': None, 'classifier__m...      0.425134
# 479  {'classifier__max_depth': None, 'classifier__m...      0.425134
#
#      std_test_f1  rank_test_f1
# 483     0.056467             1
# 482     0.056467             1
# 481     0.056467             1
# 480     0.056467             1
# 479     0.056467             1
#
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     53374
#            1       1.00      0.29      0.45        24
#
#     accuracy                           1.00     53398
#    macro avg       1.00      0.65      0.73     53398
# weighted avg       1.00      1.00      1.00     53398
#
# Confusion Matrix on Test Set:
# [[53374     0]
#  [   17     7]]

# %% [markdown]
# # 4. Storytelling With Data plot

# %% [markdown]
# Reproduce any graph of your choice in chapter seven (p. 165-185) of the Storytelling With Data book as best you can. You do not have to get the exact data values right, just the overall look and feel.
